# %%
import sys, os
from Deconvolution.BLADE import Framework
import numpy as np
from numpy import transpose as t
import itertools
import pickle
from scipy.optimize import nnls
from sklearn.svm import SVR
from sklearn.svm import NuSVR

from sklearn.metrics import mean_squared_error as mse
import pandas as pd

# modules for visualization
import qgrid
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Run BLADE with TCGA bulk and Puram scRNA-seq reference

# %% [markdown]
# #### Application of deconvolution methods
#
# From here, we will apply the following three methods for further performance comparison:
# 1. BLADE (estimation of cellular fraction + group-mode/high-resolution-mode purification)
# 2. NNLS (estimation of fraction)
# 3. SVR followed by NNLS (estimation of fraction + group-mode purification) - similar to CIBERSORTx
#
#
# ##### 1. Application of BLADE
#
# These are the key parameters used in BLADE (note that there is default settings of these parameters, if not specified):
# - Hyperparameters (`hyperpars`): `Alpha`, `Alpha0`, `Kappa0` and `SigmaY`, each of which can be defined as a list of options. BLADE takes an empirical Bayes approach to find the optimal parameter set given the all possible combinations.
# - `Nrep`: Number of repeat for evaluating each parameter configuration.
# - `Nrepfinal`: Number of repeated optimizations for the final parameter set.
# - `Njob`: Number of parallel jobs.

# %% [markdown]
# ## Prepare signature matrix as required

# %%
df_Puram_std = pd.read_csv("/home/cke/Puram/HNSCC2PuramGSE103322_qc_std.tsv",sep='\t',index_col=0)
df_Puram_mean = pd.read_csv("/home/cke/Puram/HNSCC2PuramGSE103322_qc_mean.tsv",sep='\t',index_col=0)
marker_genes = pd.read_csv("/home/cke/Puram/top100DEGs_pseudobulk.txt",header=None).iloc[0,:]

marker_genes = marker_genes.drop_duplicates()
df_Puram_std_filtered = df_Puram_std.loc[marker_genes,:]
df_Puram_mean_filtered = df_Puram_mean.loc[marker_genes,:]

df_pseudo = pd.read_csv("/home/cke/Puram/Puram_pseudobulk_fromraw.tsv",sep='\t',index_col=0).T
df_Puram_mean_log2 = np.log2(df_Puram_mean_filtered+1)

merge_genes_mean = pd.merge(df_Puram_mean_log2,df_pseudo,left_index=True,right_index=True,how='inner')
merge_genes_std = pd.merge(df_Puram_std_filtered,df_pseudo,left_index=True,right_index=True,how='inner')

print("Get mean and std exp!")

#simple tumor cell type setup, there are 10 annotated cell types
df_TCGA_shared = merge_genes_mean.iloc[:,10:]
df_shared_mean = merge_genes_mean.iloc[:,:10]
df_shared_std = merge_genes_std.iloc[:,:10]

print("Get common genes! ",df_shared_mean.shape[0])
print("cell types: ",df_shared_mean.shape[1])
print("bulk samples: ",df_TCGA_shared.shape[1])
# Out:
# Get mean and std exp!
# Get common genes!  880
# cell types:  10
# bulk samples:  17

# %%
df_Puram_mean
# Out:
#             B cell  Dendritic  Endothelial  Fibroblast  Macrophage      Mast  \
# C9orf152  0.000000   0.017683     0.028524    0.006479    0.000000  0.000000
# RPS11     5.841971   5.327779     5.893488    5.699910    5.739950  4.537083
# ELMO2     0.208097   0.674968     0.542106    0.621450    0.564073  0.791185
# CREB3L1   0.000000   0.080368     0.015094    0.134395    0.000000  0.000000
# PNMA1     0.230034   1.543609     0.737776    1.045224    0.220860  0.456808
# ...            ...        ...          ...         ...         ...       ...
# PIK3IP1   0.223408   0.426315     0.865399    0.635732    1.446469  1.883503
# SNRPD2    2.039287   1.887854     2.958933    2.501452    4.114600  1.997951
# SLC39A6   0.223141   0.414837     0.207165    0.758208    0.552769  0.483878
# CTSC      0.901751   2.988974     1.829729    1.145382    4.050639  1.284788
# AQP7      0.000000   0.000000     0.012274    0.044894    0.000000  0.031048
#
#             T cell   myocyte     other     tumor
# C9orf152  0.000989  0.000000  0.126178  0.021723
# RPS11     4.093909  5.563400  5.725872  6.394412
# ELMO2     0.553634  0.449079  0.500478  0.743162
# CREB3L1   0.000375  0.000000  0.352287  0.004988
# PNMA1     0.351467  0.395577  0.281493  0.815725
# ...            ...       ...       ...       ...
# PIK3IP1   3.408460  0.126706  1.086586  1.125250
# SNRPD2    2.076782  3.142584  3.540576  5.622199
# SLC39A6   0.343637  0.272967  0.997367  1.978218
# CTSC      1.722533  0.597943  1.556963  3.001549
# AQP7      0.001250  0.159247  0.034712  0.004262
#
# [21437 rows x 10 columns]

# %%
(marker_genes.isin(df_Puram_mean.index)==True).sum()
# Out:
# 880

# %%
df_Puram_mean.index.to_list()
# Out:
# ['C9orf152',
#  'RPS11',
#  'ELMO2',
#  'CREB3L1',
#  'PNMA1',
#  'MMP2',
#  'TMEM216',
#  'TRAF3IP2-AS1',
#  'LRRC37A5P',
#  'LOC653712',
#  'C10orf90',
#  'ZHX3',
#  'ERCC5',
#  'GPR98',
#  'RXFP3',
#  'CTAGE10P',
#  'APBB2',
#  'KLHL13',
#  'PDCL3',
#  'AEN',
#  'FRG2',
#  'DECR1',
#  'SALL1',
#  'GGT3P',
#  'CADM4',
#  'RPS18',
#  'SLC10A7',
#  'CFHR5',
#  'OR2K2',
#  'BRIX1',
#  'LMAN1',
#  'CHD8',
#  'SUMO1',
#  'MIR941-2',
#  'GP1BA',
#  'BSN-AS2',
#  'BOLA3-AS1',
#  'UQCR11',
#  'DDB1',
#  'MYO9B',
#  'MMP7',
#  'CRNKL1',
#  'XAB2',
#  'RTN1',
#  'KLHL14',
#  'ADAM21P1',
#  'TBX10',
#  'ZBTB12',
#  'UTY',
#  'CENPQ',
#  'ZAR1L',
#  'DTNBP1',
#  'KBTBD8',
#  'ZEB1',
#  'ZG16',
#  'PRKAG2-AS1',
#  'FAT4',
#  'LOC100216546',
#  'MIER1',
#  'CHD9',
#  'STK16',
#  'ARID3C',
#  'TOB2',
#  'INIP',
#  'BANK1',
#  'OR2V2',
#  'SFTA2',
#  'GRM2',
#  'PROSC',
#  'SPIN2B',
#  'PIR',
#  'IPO9',
#  'FLJ26850',
#  'EVC',
#  'CXCL13',
#  'KIAA1199',
#  'EHHADH-AS1',
#  'SORL1',
#  'NAT10',
#  'CHD1',
#  'SYN3',
#  'SLC22A2',
#  'SERPINF1',
#  'WDR34',
#  'OR7A17',
#  'POTED',
#  'EPT1',
#  'LHB',
#  'TAOK3',
#  'STK25',
#  'CDC25B',
#  'BMP3',
#  'TMEM180',
#  'MAP1LC3C',
#  'MIR564',
#  'POU3F1',
#  'HIGD1B',
#  'USP6NL',
#  'LINC00460',
#  'ABCD4',
#  'C11orf93',
#  'TEK',
#  'SLC25A46',
#  'LARP7',
#  'CD160',
#  'MT1JP',
#  'PHF20',
#  'CPNE4',
#  'HNF1A-AS1',
#  'GTPBP1',
#  'RAB33B',
#  'GLUD1P7',
#  'ALDOC',
#  'ZNF212',
#  'NUDT1',
#  'FAM170B-AS1',
#  'RFPL2',
#  'ZNF83',
#  'IPW',
#  'MIR630',
#  'GDPD5',
#  'PDCD4',
#  'CEP350',
#  'ARL14EPL',
#  'OR10A2',
#  'CST7',
#  'SELL',
#  'CIAO1',
#  'RNF223',
#  'OR8J3',
#  'LTBP4',
#  'DCAF4L1',
#  'SIRT6',
#  'CCL19',
#  'PPIL1',
#  'GBP7',
#  'STK17A',
#  'OR9G1',
#  'ABR',
#  'PCDHA13',
#  'FOXE1',
#  'SIAH3',
#  'RIMBP3B',
#  'GML',
#  'CNGA3',
#  'CD38',
#  'ZDHHC6',
#  'NEFH',
#  'PGBD5',
#  'CTDSP2',
#  'ZNF257',
#  'RMND5B',
#  'CCNY',
#  'EXOSC7',
#  'C11orf88',
#  'ROR2',
#  'LOC338758',
#  'MAOA',
#  'TNNT3',
#  'GYPC',
#  'MIR3120',
#  'C7orf33',
#  'AP4B1-AS1',
#  'RNF4',
#  'EMC1',
#  'F8A1',
#  'HDAC7',
#  'PLEKHG4',
#  'GRB2',
#  'LINC00597',
#  'AGPHD1',
#  'HIST1H2AD',
#  'DUS3L',
#  'EIF1',
#  'FPGT',
#  'CHST15',
#  'GPN2',
#  'GDF10',
#  'COQ9',
#  'TRAPPC9',
#  'DKFZP434I0714',
#  'GCC2',
#  'RARRES3',
#  'PLXNA1',
#  'KIAA0100',
#  'PMF1',
#  'FNDC1',
#  'HS2ST1',
#  'CRELD2',
#  'CD82',
#  'C8G',
#  'SPINK14',
#  'PIRT',
#  'MMP16',
#  'LOC100133091',
#  'PTP4A2',
#  'OR4M2',
#  'C11orf73',
#  'HPCA',
#  'SEC14L1',
#  'METTL25',
#  'NME8',
#  'EMILIN1',
#  'CHFR',
#  'NDUFS4',
#  'TP53TG3C',
#  'COL18A1',
#  'PDZD3',
#  'FAXC',
#  'C9orf16',
#  'ERBB2IP',
#  'FUS',
#  'EMX2',
#  'TF',
#  'CXorf56',
#  'CLCN4',
#  'NPR1',
#  'ELAC2',
#  'CELA1',
#  'ASS1',
#  'USP42',
#  'EMC8',
#  'SEC23IP',
#  'POLR2J',
#  'UQCRC1',
#  'LOC729603',
#  'ERVV-2',
#  'POLG',
#  'ADAM23',
#  'TFR2',
#  'RICTOR',
#  'GRXCR2',
#  'FLJ42709',
#  'IDO2',
#  'HLA-J',
#  'C19orf55',
#  'FONG',
#  'SNAPC1',
#  'GNA11',
#  'LOC654342',
#  'FSIP1',
#  'CELA3A',
#  'UPF3A',
#  'IGSF11',
#  'LAGE3',
#  'CHST6',
#  'UNC13B',
#  'TTLL4',
#  'ZNF687',
#  'FLJ45974',
#  'SDC2',
#  'METTL21A',
#  'COX7A2',
#  'CETN4P',
#  'LOC100132707',
#  'LAMB4',
#  'PDP1',
#  'LRRTM3',
#  'GPHB5',
#  'AHCYL2',
#  'FLJ39739',
#  'TRIM64C',
#  'HABP4',
#  'TMEM125',
#  'CNTN2',
#  'ASNSD1',
#  'FUT4',
#  'BAGE4',
#  'LINC00675',
#  'RP9',
#  'ARAP1',
#  'CDH8',
#  'AGPS',
#  'PP14571',
#  'CLEC4GP1',
#  'UNG',
#  'LOC284344',
#  'GSTP1',
#  'DCUN1D5',
#  'SLC9A3R1',
#  'FAM218A',
#  'LILRA6',
#  'CHMP7',
#  'REM2',
#  'MIR637',
#  'DNHD1',
#  'FKBP4',
#  'ZNF350',
#  'BST1',
#  'KISS1R',
#  'NCR2',
#  'MIR3690',
#  'UBE2W',
#  'OR2T29',
#  'SNORA78',
#  'KRT15',
#  'C10orf99',
#  'SCN11A',
#  'GFI1',
#  'FHL1',
#  'SMC6',
#  'OSGEP',
#  'GATA1',
#  'TTTY14',
#  'LPIN3',
#  'RPL4',
#  'RBPMS',
#  'LOC100506172',
#  'PRPF3',
#  'EMR1',
#  'SPATA19',
#  'XCR1',
#  'IRX3',
#  'ELFN1',
#  'RBM6',
#  'CYSTM1',
#  'KLF4',
#  'IFITM10',
#  'MIR5010',
#  'LOC729177',
#  'UNC5CL',
#  'C16orf71',
#  'LOC100527964',
#  'LOC100128252',
#  'SEBOX',
#  'BTK',
#  'KRCC1',
#  'SYTL5',
#  'PRND',
#  'PIGL',
#  'MOB1B',
#  'HUS1',
#  'DNAJC30',
#  'HID1',
#  'UIMC1',
#  'FXYD2',
#  'C17orf77',
#  'ZNF667',
#  'PTGES3L-AARSD1',
#  'ZCCHC12',
#  'TFEC',
#  'ATP7B',
#  'C2orf78',
#  'POLD2',
#  'ABCC6P1',
#  'C1orf145',
#  'ACOT2',
#  'HIST1H4I',
#  'PPARGC1A',
#  'ETFA',
#  'ZNF146',
#  'POLRMT',
#  'KLHL6',
#  'LOC440311',
#  'NENF',
#  'HOXB5',
#  'ARGFX',
#  'PRSS22',
#  'CASC4',
#  'LOC400752',
#  'LOC338799',
#  'GTSF1',
#  'CUL4B',
#  'CENPJ',
#  'PITX1',
#  'AKIRIN1',
#  'CELSR3',
#  'LOC100132735',
#  'DNAJC9',
#  'ZNF568',
#  'ITSN1',
#  'EHBP1L1',
#  'MT1DP',
#  'DCTN1',
#  'LIN28B',
#  'TNKS2',
#  'TMEM241',
#  'DUX4L3',
#  'C1QBP',
#  'CADPS2',
#  'SRMS',
#  'GJA9',
#  'TRIM45',
#  'LOC392232',
#  'TCP1',
#  'TMED7',
#  'CMA1',
#  'CENPL',
#  'PTCRA',
#  'FST',
#  'VWCE',
#  'PAWR',
#  'TBC1D3B',
#  'SNORD91A',
#  'ABCC12',
#  'SYCE3',
#  'LDLR',
#  'CXCR2P1',
#  'ASTN2',
#  'TAB2',
#  'GPATCH8',
#  'TANC2',
#  'KIF4A',
#  'FAM161A',
#  'PGM1',
#  'CPD',
#  'SNCAIP',
#  'DCT',
#  'ANXA8',
#  'HLA-DOA',
#  'LOC340073',
#  'UPK1B',
#  'DNAJB4',
#  'UGT1A8',
#  'HIST1H4L',
#  'GOLGA8EP',
#  'PECR',
#  'WFIKKN1',
#  'HSPA2',
#  'SERP1',
#  'SYDE2',
#  'CNTNAP3B',
#  'C15orf60',
#  'TACR2',
#  'SVOPL',
#  'NUP85',
#  'SNORA18',
#  'CD177',
#  'PIGG',
#  'LGR5',
#  'MIR3671',
#  'LINC00348',
#  'LOC574538',
#  'SCARNA2',
#  'RAB5A',
#  'LRRC16B',
#  'FLJ13224',
#  'DCAF11',
#  'USP9Y',
#  'C7orf53',
#  'PLEKHM3',
#  'LRP1B',
#  'XAF1',
#  'TMEM244',
#  'ENKUR',
#  'ANKDD1A',
#  'ABCG8',
#  'MIR4444-1',
#  'LOC100505474',
#  'DAND5',
#  'SPAG6',
#  'LOC100133161',
#  'ZDHHC22',
#  'CCDC60',
#  'THOC7',
#  'TCTA',
#  'GGTLC2',
#  'B2M',
#  'LPPR4',
#  'C6orf141',
#  'SQLE',
#  'LOC100129046',
#  'SEPHS1',
#  'GLIPR2',
#  'PLRG1',
#  'SPG7',
#  'ZNF614',
#  'ZMYM6NB',
#  'PARD6G',
#  'FAM41C',
#  'MIR221',
#  'LINC00516',
#  'PTCHD3P1',
#  'INPP5B',
#  'GRPEL2',
#  'PPID',
#  'TRIM56',
#  'UBE2J1',
#  'IL20RA',
#  'SNORA75',
#  'UTS2R',
#  'SAFB2',
#  'DNAJC25',
#  'KLRG1',
#  'NEURL3',
#  'MS4A8B',
#  'E2F4',
#  'CLEC4M',
#  'TAC1',
#  'GYPA',
#  'TRAIP',
#  'LOC284412',
#  'LOC729852',
#  'KIAA0232',
#  'ERCC8',
#  'GPX4',
#  'KIAA0368',
#  'MSS51',
#  'GPR157',
#  'FAM199X',
#  'CTAGE4',
#  'ALG9',
#  'BTBD10',
#  'SDK2',
#  'BAIAP3',
#  'RABGGTB',
#  'ANKRD40',
#  'KRT74',
#  'CALCOCO2',
#  'LOC100128993',
#  'SNCA',
#  'SPATS2L',
#  'ESRRB',
#  'SLC48A1',
#  'ARHGAP26',
#  'TDRD9',
#  'PRCD',
#  'CDK16',
#  'KLRC4',
#  'HRAS',
#  'JAGN1',
#  'BSDC1',
#  'RNF43',
#  'NDUFAF1',
#  'PHF12',
#  'HOTAIRM1',
#  'KRTAP4-8',
#  'FOLR2',
#  'PLAC8L1',
#  'LYZL6',
#  'LEMD1-AS1',
#  'WSB1',
#  'PROS1',
#  'SOCS4',
#  'PSMB8',
#  'SDR39U1',
#  'DDIT4L',
#  'TBCCD1',
#  'MGC34796',
#  'SCARNA16',
#  'ZBTB7C',
#  'AP2S1',
#  'VAT1',
#  'SHANK3',
#  'TUFM',
#  'OR7E5P',
#  'THEG',
#  'KRT34',
#  'SGSM3',
#  'TOMM22',
#  'SOCS3',
#  'CPO',
#  'POP4',
#  'MALL',
#  'PARK2',
#  'OR1B1',
#  'GPR124',
#  'TMEM132A',
#  'LCE1E',
#  'DACT3-AS1',
#  'RUVBL2',
#  'CGRRF1',
#  'ACPL2',
#  'PIANP',
#  'WNT10B',
#  'GTF2IRD2P1',
#  'BAIAP2L2',
#  'LOC728724',
#  'ISCA1',
#  'RPAP1',
#  'NXPE2',
#  'RPL27',
#  'NLRP9',
#  'EPN1',
#  'SLC35A1',
#  'GAL',
#  'SLC14A2',
#  'RDH11',
#  'FAM138F',
#  'SERF2-C15ORF63',
#  'AUH',
#  'MBD2',
#  'ABHD14B',
#  'SPHAR',
#  'PIGT',
#  'ALAS1',
#  'FOXO1',
#  'PPP1R17',
#  'CRLF3',
#  'OR5W2',
#  'FARS2',
#  'LOC285593',
#  'CCDC28A',
#  'NPHP3',
#  'LOC285627',
#  'PYURF',
#  'TSEN54',
#  'MAGI2-AS3',
#  'STH',
#  'ZC3H14',
#  'HMGXB4',
#  'CBX2',
#  'CXADRP2',
#  'RBMXL1',
#  'CRTAP',
#  'DDX50',
#  'TBPL2',
#  'STYXL1',
#  'EFCAB4A',
#  'BLVRB',
#  'A1BG-AS1',
#  'SNORA68',
#  'CCZ1B',
#  'MMP24',
#  'GRID1',
#  'BANF1',
#  'CATSPER2P1',
#  'HMBS',
#  'FAM13A',
#  'SLC25A24',
#  'LINC00161',
#  'SLC25A15',
#  'MRO',
#  'CCDC129',
#  'ACER3',
#  'LOC100500773',
#  'FAM84B',
#  'TDP1',
#  'C11orf57',
#  'RFK',
#  'ARHGAP8',
#  'ZFYVE9',
#  'WIBG',
#  'GBA2',
#  'NDUFB3',
#  'HSD17B13',
#  'KRTAP5-11',
#  'GRIN3A',
#  'FLJ34503',
#  'FMNL1',
#  'FLJ41200',
#  'CHTOP',
#  'SEPT7',
#  'GNLY',
#  'FAM223A',
#  'GRAMD1C',
#  'ZNF165',
#  'USP38',
#  'FAM83A',
#  'ARMCX3',
#  'ARHGDIB',
#  'AK1',
#  'ACSS3',
#  'KIAA1045',
#  'C4B',
#  'DNAJB13',
#  'MUC22',
#  'TRIM77',
#  'HIST1H4B',
#  'FAM20B',
#  'HES2',
#  'FAM73B',
#  'CYP4F24P',
#  'NEDD8-MDP1',
#  'INTS7',
#  'AMPH',
#  'ZNF775',
#  'SNORD61',
#  'USP17L7',
#  'UCKL1',
#  'SNORA23',
#  'HNRNPH1',
#  'ALDH1L1',
#  'COX16',
#  'SLC23A1',
#  'THAP4',
#  'RBM4B',
#  'OGFRL1',
#  'PPP1R15A',
#  'BMF',
#  'MAN1A1',
#  'NKAIN1',
#  'NLGN4X',
#  'LOC399715',
#  'IFNE',
#  'ALOX12',
#  'RB1CC1',
#  'NEIL2',
#  'TMEM255B',
#  'EIF4E',
#  'SIGLEC15',
#  'ABHD5',
#  'EXOC4',
#  'PRAMEF14',
#  'HEATR5A',
#  'SLC29A4',
#  'BATF2',
#  'HTR4',
#  'GUSBP5',
#  'URGCP',
#  'EMB',
#  'TRAF6',
#  'LPAR3',
#  'LMNB1',
#  'CKMT1B',
#  'LINC00320',
#  'FAM19A5',
#  'SHE',
#  'IFIT1B',
#  'CACNA1C-AS4',
#  'PIK3C2B',
#  'RBM12B-AS1',
#  'AKR1E2',
#  'USP15',
#  'MIR548Z',
#  'TCEAL2',
#  'PTGER2',
#  'FAM184B',
#  'SLC31A1',
#  'LOC727915',
#  'IFT172',
#  'ST7L',
#  'GFOD1',
#  'ADAM29',
#  'BET3L',
#  'PKN3',
#  'C15orf26',
#  'NCOR1P1',
#  'CNTD1',
#  'COMMD1',
#  'WASH7P',
#  'NTRK2',
#  'FOXN3',
#  'MFGE8',
#  'PFKFB2',
#  'TAS2R4',
#  'MIR1245A',
#  'ENTHD1',
#  'MIR765',
#  'PRMT5',
#  'ZSCAN12P1',
#  'HIST2H3A',
#  'DCAF4',
#  'LCLAT1',
#  'TSKU',
#  'PDLIM1',
#  'KRTCAP3',
#  'KCNS2',
#  'RNF126',
#  'MIR4741',
#  'CEP63',
#  'CLIC4',
#  'ACR',
#  'KLK7',
#  'ALOX5AP',
#  'RIPK3',
#  'C19orf18',
#  'BIRC6',
#  'ZNF16',
#  'RFT1',
#  'ELP6',
#  'APOC1P1',
#  'SLC8A2',
#  'TACC1',
#  'ITGAD',
#  'SH3PXD2B',
#  'SAMHD1',
#  'EPC2',
#  'C20orf85',
#  'ATP13A2',
#  'ASIC5',
#  'KRT4',
#  'SNX18',
#  'MDM2',
#  'CAPNS1',
#  'SNORD110',
#  'PCDH20',
#  'SNHG15',
#  'OR2C1',
#  'KLHDC3',
#  'IPPK',
#  'EFHD2',
#  'NBEA',
#  'GALR3',
#  'ABCA6',
#  'CLDN3',
#  'AKT2',
#  'EGFR',
#  'ZDHHC3',
#  'SLC25A4',
#  'CYB5B',
#  'TESPA1',
#  'NDRG1',
#  'CPXM1',
#  'CACNA1C-AS1',
#  'CDHR4',
#  'ANKRD30BP2',
#  'ZNF285',
#  'MRPL46',
#  'FMO6P',
#  'FARP2',
#  'SNORD50A',
#  'LOC100270746',
#  'MAPKAPK3',
#  'LDHAL6B',
#  'NCAM2',
#  'PRKD2',
#  'ZFP36L1',
#  'CYSLTR1',
#  'HIST1H2AJ',
#  'CCNB2',
#  'ZNF10',
#  'TMEM175',
#  'FAM134A',
#  'TIGD4',
#  'FLJ13197',
#  'PCNP',
#  'TBC1D3G',
#  'SLX1B-SULT1A4',
#  'CREB1',
#  'NAA38',
#  'C9orf57',
#  'FAM225A',
#  'FAM22F',
#  'TMPRSS3',
#  'C4orf32',
#  'LAT',
#  'LOC392196',
#  'KCNA3',
#  'SKIV2L2',
#  'ROPN1B',
#  'ZHX2',
#  'FKSG29',
#  'CDT1',
#  'CD28',
#  'ZNF624',
#  'SEPT2',
#  'SOHLH2',
#  'MCOLN3',
#  'MASP2',
#  'ZNRF3',
#  'GPATCH3',
#  'AGL',
#  'QRICH2',
#  'PSD4',
#  'PRR20B',
#  'CCNB1IP1',
#  'LOC100289187',
#  'ENPP7',
#  'OBFC1',
#  'KCNG3',
#  'ENPEP',
#  'C14orf79',
#  'SCT',
#  'SKI',
#  'SHISA4',
#  'SEC61G',
#  'CAPN11',
#  'ATXN7L3',
#  'SNORA1',
#  'FAIM',
#  'DBNDD1',
#  'SZT2',
#  'ANKRD36',
#  'GABRP',
#  'TACSTD2',
#  'PPP2R2A',
#  'EIF3J',
#  'ZNF541',
#  'TEKT4',
#  'PVALB',
#  'LOC100128420',
#  'RTCA',
#  'F10',
#  'FAM134C',
#  'COMP',
#  'ZNF865',
#  'TMEM52B',
#  'SCLT1',
#  'TAL1',
#  'LOC493754',
#  'ACSL1',
#  'ABCC5',
#  'POU4F1-AS1',
#  'RBBP7',
#  'ABL1',
#  'PTPRG',
#  'NCOR1',
#  'TXNRD1',
#  'SPINK4',
#  'UBE2H',
#  'BRDT',
#  'LRRC26',
#  'FAM156A',
#  'C8orf31',
#  'SLC6A8',
#  'CCNE2',
#  'CALCR',
#  'CDC45',
#  'LINC00685',
#  'CWC22',
#  'PPP1CB',
#  'ABHD8',
#  'ARF5',
#  'SLC24A4',
#  'CCT3',
#  'ZNF121',
#  'SLC5A10',
#  'SLC3A2',
#  'OR13A1',
#  'RAD50',
#  'IER5',
#  'MTHFD1L',
#  'MBTPS2',
#  'MVK',
#  'RBMY1E',
#  'FAM110D',
#  'NCL',
#  'PSMG3-AS1',
#  'PSMD10',
#  'MOBP',
#  'HRH1',
#  'HCG18',
#  'C5orf30',
#  'SPANXA1',
#  'RASGRP3',
#  'NUDT16L1',
#  'C16orf11',
#  'LOC284837',
#  'PRKRIP1',
#  'LOC285972',
#  'FBXO47',
#  'MED21',
#  'KIAA1239',
#  'SYT11',
#  'NTSR2',
#  'BTBD18',
#  'SPTBN2',
#  'LRMP',
#  'BHLHE40',
#  'KLHL31',
#  'RNF111',
#  'C17orf98',
#  'C11orf92',
#  'PTH',
#  'IST1',
#  'KIAA0895',
#  'P2RY10',
#  'NME5',
#  'DDX21',
#  'LRSAM1',
#  'HDAC11',
#  'VMO1',
#  'MTO1',
#  'ADAR',
#  'P2RX1',
#  'EN2',
#  'MIR2276',
#  'TM9SF2',
#  'INHBE',
#  'DLG5-AS1',
#  'TCTE3',
#  'TOX2',
#  'PSG10P',
#  'MED15',
#  'CASR',
#  'MTPN',
#  'UNC50',
#  'C21orf33',
#  'IRF2',
#  'PGR',
#  'SPATA6L',
#  'GPR84',
#  'SRPX',
#  'BRE',
#  'FRMD8P1',
#  'FGF10',
#  'SDC3',
#  'TMEM218',
#  'SOX6',
#  'RPUSD2',
#  'ZSCAN31',
#  'MAPK11',
#  'TBC1D22A',
#  'ZNF204P',
#  'COL4A6',
#  'TOMM70A',
#  'MIR22',
#  'NAB1',
#  'ASIC4',
#  'TSPAN18',
#  'TRMT10A',
#  'ZNF559-ZNF177',
#  'MED31',
#  'LOC100507003',
#  'ZNF532',
#  'PLG',
#  'CAPSL',
#  'ASB14',
#  'CA8',
#  ...]

# %%
'SFTA2' in df_shared_mean.index
# Out:
# False

# %%
'SFTA2' in marker_genes
# Out:
# False

# %%
df_TCGA_shared
# Out:
#                     0           6         7          8          10  \
# AREG       218.775090    78.13442   0.00000   30.09585   66.871320
# QPCTL      289.076350   237.98935   2.66097  101.38164   73.388010
# CNN3       147.127440   914.64370  27.03170  273.27316  155.587620
# MTRNR2L6   671.693000   939.34094   7.06690  251.27254  242.529560
# PTPN1      283.433700   207.85945   3.61530   44.30932  128.515720
# ...               ...         ...       ...        ...         ...
# FOXP1      522.212770   519.47284   8.76590  270.51523  102.644196
# RABAC1     484.293640   838.13170   4.33760  178.75845  328.779970
# PTGS1       28.874298    50.79470   0.00000   28.10949   28.099714
# ZNF793     248.700580   211.03482   2.46182  104.48741   63.530834
# DDX5      1910.132200  1808.19980  23.74510  463.14260  410.335750
#
#                   12          13          16          17          18  \
# AREG       84.348800  168.346700   449.64160   686.85860   688.41724
# QPCTL     136.335500   54.209880   533.28320   268.94766   401.33150
# CNN3       43.292324  108.880470  1093.32860  1417.55380   927.66266
# MTRNR2L6  316.656040  201.426300  1414.46350  1477.01710  1467.85110
# PTPN1     107.859580  157.980830   368.82138   500.62790   429.32742
# ...              ...         ...         ...         ...         ...
# FOXP1     273.455380  212.604430   973.37665   539.08680   853.98930
# RABAC1    180.154500  157.988020  1451.76440  1335.02880  1437.67490
# PTGS1       0.137403   31.529453   148.61210   375.19850   136.91693
# ZNF793    156.765950   52.710938   475.52510   215.03966   351.34436
# DDX5      958.408100  538.337600  3541.70000  2692.09960  3014.32400
#
#                    20          22          23          24          25  \
# AREG        90.370380   212.65027   14.244100  167.200200   830.91920
# QPCTL      333.781700    96.20364   34.601234   84.978516   497.60614
# CNN3       828.252000   510.68524    0.000000  575.223700  2048.17380
# MTRNR2L6  1762.216700   825.36540  299.477400  548.414730  3840.45000
# PTPN1      364.492520   193.16628   44.852200  159.850360   749.53280
# ...               ...         ...         ...         ...         ...
# FOXP1      314.579380   186.06172   46.034360  278.852050  1270.30960
# RABAC1    1531.085100   515.56750  121.890300  478.761350  2308.32840
# PTGS1        8.388001   158.25346    0.000000  203.309310   200.55597
# ZNF793     303.478850    79.37739   35.850800   67.430690   485.51733
# DDX5      3129.357000  1034.55200  326.113300  736.469700  4214.50400
#
#                   26          28
# AREG       270.71954   409.97540
# QPCTL      260.82324   346.22168
# CNN3      1599.81350  2626.36450
# MTRNR2L6  2390.72780  3591.45500
# PTPN1      316.16910   669.48114
# ...              ...         ...
# FOXP1      536.54280  1039.81290
# RABAC1    1064.41670  2170.86940
# PTGS1      100.36076   283.33344
# ZNF793     256.58210   324.74176
# DDX5      2410.57930  3589.04930
#
# [880 rows x 17 columns]

# %%
# writing a list of all DEGs
import csv
with open("compare_genes_test.txt",'w') as f:
    write = csv.writer(f)
    write.writerow(df_Puram_mean.index.tolist())

# %%
df_shared_mean
# Out:
#             B cell  Dendritic  Endothelial  Fibroblast  Macrophage      Mast  \
# AREG      1.248354   1.327800     0.087278    0.028747    2.251044  2.637694
# QPCTL     0.802654   0.761660     0.925610    0.765424    0.636664  0.910067
# CNN3      0.014843   0.962302     2.804872    2.759271    0.232031  0.092085
# MTRNR2L6  2.376320   2.146333     2.274464    2.592525    2.086993  2.113999
# PTPN1     1.810149   2.196046     0.710466    0.832199    1.729778  0.826140
# ...            ...        ...          ...         ...         ...       ...
# FOXP1     0.509221   2.284009     1.939652    1.537203    1.119101  2.279452
# RABAC1    2.723898   1.194062     2.216930    2.199098    1.612882  1.344311
# PTGS1     0.074091   0.000000     0.153627    0.464268    1.180230  2.493842
# ZNF793    0.689719   0.780146     0.864382    0.720488    0.611700  0.775994
# DDX5      2.626543   3.076712     2.985586    2.876893    2.895041  2.789542
#
#             T cell   myocyte     other     tumor
# AREG      0.764705  0.384740  0.989876  1.242421
# QPCTL     1.116926  0.682296  0.967251  0.577489
# CNN3      0.053545  1.463287  1.925831  1.733607
# MTRNR2L6  1.957030  2.438877  2.289440  2.409220
# PTPN1     0.877162  0.317696  0.670670  1.034497
# ...            ...       ...       ...       ...
# FOXP1     1.532416  0.239747  1.461023  0.998507
# RABAC1    1.321400  1.529787  1.928181  2.106459
# PTGS1     0.009088  0.016448  0.141811  0.506399
# ZNF793    1.084352  0.884953  0.875415  0.511459
# DDX5      3.020411  2.398237  2.560140  2.764878
#
# [880 rows x 10 columns]

# %%
df_shared_std
# Out:
#             B cell  Dendritic  Endothelial  Fibroblast  Macrophage      Mast  \
# AREG      2.527448   2.783769     0.473254    0.301962    3.768015  3.394832
# QPCTL     0.649059   0.374258     0.743219    0.613191    0.329033  0.720361
# CNN3      0.082777   2.058329     2.096504    2.223280    0.801207  0.458830
# MTRNR2L6  2.350267   1.704151     1.594141    1.506708    1.672132  1.805756
# PTPN1     2.250812   1.999035     1.366978    1.559267    1.863888  1.474077
# ...            ...        ...          ...         ...         ...       ...
# FOXP1     1.229674   1.781295     1.905105    1.902467    1.303177  1.833933
# RABAC1    2.614484   2.168226     2.874448    3.007220    2.257725  2.534091
# PTGS1     0.455972   0.000000     0.650487    1.246237    1.923792  2.439153
# ZNF793    0.341631   0.402770     0.516331    0.398696    0.525262  0.387454
# DDX5      2.511143   1.441813     1.520522    2.025952    0.866882  2.510397
#
#             T cell   myocyte     other     tumor
# AREG      2.065681  1.172476  2.057478  2.015638
# QPCTL     0.644929  0.799138  0.926944  0.520956
# CNN3      0.404193  2.471317  2.809141  2.032585
# MTRNR2L6  1.488867  2.419163  2.255698  1.664874
# PTPN1     1.896134  1.011864  1.336831  1.301459
# ...            ...       ...       ...       ...
# FOXP1     2.299160  0.576199  2.024939  1.173314
# RABAC1    2.732818  2.093489  2.915351  2.120058
# PTGS1     0.195719  0.049978  0.661601  0.994970
# ZNF793    0.469683  0.759592  0.777809  0.396856
# DDX5      2.248544  2.515233  2.687122  1.281431
#
# [880 rows x 10 columns]

# %%
df_TCGA_shared.to_numpy().shape
# Out:
# (880, 17)

# %%
hyperpars = {
    'Alpha': [1, 10],
    'Alpha0': [0.1, 1, 5],
    'Kappa0': [1, 0.5, 0.1],
    'SY': [1,0.3,0.5],
}

Nrep=3
Nrepfinal=10
Njob=10

# %%
print("start BLADE!")
Y = df_TCGA_shared.to_numpy()
mean = df_shared_mean.to_numpy() 
sd = df_shared_std.to_numpy() 

outfile = '/home/cke/BLADE/data/Puramfiltered_pseudobulk_BLADEout_2.pickle'

final_obj, best_obj, best_set, outs = Framework(
    mean, sd, Y,
    Alphas=hyperpars['Alpha'], Alpha0s=hyperpars['Alpha0'], 
    Kappa0s=hyperpars['Kappa0'], SYs=hyperpars['SY'],
    Nrep=Nrep, Njob=Njob, Nrepfinal=Nrepfinal)

pickle.dump(
    {
        'final_obj': final_obj,
        'best_obj': best_obj,
        'best_set': best_set,
        'outs' : outs
    }, open(outfile, 'wb')
    )

# In[ ]:
# Out:
# start BLADE!
# all of 880 genes are used for optimization.
# All samples are used during the optimization.
# Initialization with Support vector regression
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   1 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=10)]: Done   2 out of  17 | elapsed:    1.2s remaining:    9.1s
# [Parallel(n_jobs=10)]: Done   4 out of  17 | elapsed:    1.2s remaining:    4.0s
# [Parallel(n_jobs=10)]: Done   6 out of  17 | elapsed:    1.2s remaining:    2.3s
# [Parallel(n_jobs=10)]: Done   8 out of  17 | elapsed:    1.3s remaining:    1.4s
# [Parallel(n_jobs=10)]: Done  10 out of  17 | elapsed:    1.4s remaining:    1.0s
# [Parallel(n_jobs=10)]: Done  12 out of  17 | elapsed:    1.4s remaining:    0.6s
# [Parallel(n_jobs=10)]: Done  14 out of  17 | elapsed:    1.4s remaining:    0.3s
# [Parallel(n_jobs=10)]: Done  17 out of  17 | elapsed:    1.7s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# No feature filtering is done (fsel = 0)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done   5 tasks      | elapsed:  1.7min
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done  12 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:  3.2min
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=10)]: Done  41 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=10)]: Done  52 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=10)]: Done  65 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=10)]: Done  78 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=10)]: Done  93 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=10)]: Done 108 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=10)]: Done 125 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=10)]: Done 142 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=10)]: Done 160 out of 162 | elapsed: 16.4min remaining:   12.3s
# [Parallel(n_jobs=10)]: Done 162 out of 162 | elapsed: 16.6min finished
# Done optimization, elapsed time (min): 16.853661664326985
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 14>()
#       6 outfile = './BLADE/data/Puramfiltered_pseudobulk_BLADEout_2.pickle'
#       8 final_obj, best_obj, best_set, outs = Framework(
#       9     mean, sd, Y,
#      10     Alphas=hyperpars['Alpha'], Alpha0s=hyperpars['Alpha0'],
#      11     Kappa0s=hyperpars['Kappa0'], SYs=hyperpars['SY'],
#      12     Nrep=Nrep, Njob=Njob, Nrepfinal=Nrepfinal)
#      14 pickle.dump(
#      15     {
#      16         'final_obj': final_obj,
#      17         'best_obj': best_obj,
#      18         'best_set': best_set,
#      19         'outs' : outs
# ---> 20     }, open(outfile, 'wb')
#      21     )
#
# FileNotFoundError: [Errno 2] No such file or directory: './BLADE/data/Puramfiltered_pseudobulk_BLADEout_2.pickle'

# %%
outfile = '/home/cke/BLADE/data/Puramfiltered_pseudobulk_BLADEout_2.pickle'

pickle.dump(
    {
        'final_obj': final_obj,
        'best_obj': best_obj,
        'best_set': best_set,
        'outs' : outs
    }, open(outfile, 'wb')
    )

# %% [markdown]
# Given the configuration above, BLADE is applied to each of the simulation dataset created previously.
#
# BLADE produce several outcomes:
# - `final_obj`: final BLADE object with optimized variational parameters
# - `best_obj`: BLADE object trained with the best parameter set found by the Empirical Bayes framework. Empirical Bayes framework is applied after selecting a subset of samples (5 samples; indicated by `Ind_sample` below), and thus the outcome contains only 5 samples. If `Nsample` <= 5, `final_obj` is identical to `best_obj`.
# - `best_set`: Best parameter set defined by Empirical Bayes framework.
# - `outs`: Outcome of BLADE for every possible combination of hyperparameters, used in the Empirical Bayes framework.

# %% [markdown]
# - There are nan in mean and std matrix! NAs are filled with 0?
#
# full tumor type setup:
# - ngenes = 21706 common genes
# - ncells = 24, including all 16 tumor types
# - nsample = 546
#
#
# simple tumor type setup:
# - ngenes = 21706 common genes
# - ncells = 10, all tumor types are merged, including one NA type?
# - nsample = 546
# - marker genes = 900 (including 9 genes not shared)

# %% [markdown]
# ### test run with a small subset of scrna reference, take randomly 1000 genes from both ref and bulk counts
# > reduced hyperparam combinations

# %%
hyperpars_test = {
    'Alpha': [1, 10],
    'Alpha0': [0.1, 1, 5],
    'Kappa0': [1, 0.5, 0.1],
    'SY': [1,0.3,0.5],
}

Nrep=3
Nrepfinal=10
Njob=10

df_mean_sample = df_shared_mean.sample(n=2000)
df_std_sample = df_shared_std[df_shared_std.index.isin(df_mean_sample.index)]
Y_sample = df_TCGA_shared[df_TCGA_shared.index.isin(df_mean_sample.index)]

Y = Y_sample.to_numpy()
mean = df_mean_sample.to_numpy() 
sd = df_std_sample.to_numpy()

outfile = './BLADE/data/PuramTCGA_BLADE_Sample2000.pickle'

final_obj, best_obj, best_set, outs = Framework(
    mean, sd, Y,
    Alphas=hyperpars_test['Alpha'], Alpha0s=hyperpars_test['Alpha0'], 
    Kappa0s=hyperpars_test['Kappa0'], SYs=hyperpars_test['SY'],
    Nrep=Nrep, Njob=Njob, Nrepfinal=Nrepfinal)

pickle.dump(
    {
        'final_obj': final_obj,
        'best_obj': best_obj,
        'best_set': best_set,
        'outs' : outs
    }, open(outfile, 'wb')
    )
# Out:
# all of 2000 genes are used for optimization.
# All samples are used during the optimization.
# Initialization with Support vector regression
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   5 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=10)]: Done  12 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=10)]: Done  41 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=10)]: Done  52 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=10)]: Done  65 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=10)]: Done  78 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=10)]: Done  93 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=10)]: Done 108 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=10)]: Done 125 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=10)]: Done 142 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=10)]: Done 161 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=10)]: Done 201 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=10)]: Done 222 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=10)]: Done 245 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=10)]: Done 268 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=10)]: Done 293 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=10)]: Done 318 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=10)]: Done 345 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=10)]: Done 372 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=10)]: Done 401 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=10)]: Done 461 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=10)]: Done 492 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=10)]: Done 525 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=10)]: Done 546 out of 546 | elapsed:   46.5s finished
# No feature filtering is done (fsel = 0)
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:589: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 2d, A))
#   g_Exp = g_Exp_Beta(Nu, Omega, Beta, B0, Ngene, Ncell, Nsample)
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done   5 tasks      | elapsed: 61.8min
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done  12 tasks      | elapsed: 166.9min
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done  21 tasks      | elapsed: 271.8min
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:809: RuntimeWarning: divide by zero encountered in log
#   return -self.Nsample*np.sum(np.log(Omega))
# /home/cke/miniconda3/envs/BLADE/lib/python3.10/site-packages/Deconvolution/BLADE.py:863: RuntimeWarning: invalid value encountered in double_scalars
#   return PX+PY+PF-QX-QF
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed: 417.7min

# %% [markdown]
# ## Results

# %%
BLADE_out = pickle.load(open("/home/cke/BLADE/data/Puramfiltered_pseudobulk_BLADEout_2.pickle", 'rb'))

# %%
obj = BLADE_out['final_obj']
    
outcomes = {
    'BLADE': {
        'Fraction': t(obj.ExpF(obj.Beta)), 
        'Signature': np.mean(obj.Nu, 0), #group mode purification
        'HighRes': obj.Nu                #highresolution mode purification
    }}

# %%
obj

# %%
outcomes['BLADE']['HighRes']
# Out:
# array([[[ 1.26149499e+00,  1.32880508e+00,  8.74101227e-02, ...,
#           3.84936899e-01,  9.92568033e-01,  1.24586847e+00],
#         [ 8.03453672e-01,  7.61808350e-01,  9.25836741e-01, ...,
#           6.82371711e-01,  9.68220959e-01,  5.77717040e-01],
#         [ 1.54093262e-02,  9.63745928e-01,  2.80614574e+00, ...,
#           1.45993435e+00,  1.91034487e+00,  1.73744816e+00],
#         ...,
#         [ 7.55731232e-02, -1.09473318e-02,  1.53909305e-01, ...,
#           1.65810050e-02,  1.43240653e-01,  5.07403116e-01],
#         [ 6.90456164e-01,  7.80346420e-01,  8.64612947e-01, ...,
#           8.85071832e-01,  8.76323928e-01,  5.11718603e-01],
#         [ 2.63344482e+00,  3.07816053e+00,  2.98704538e+00, ...,
#           2.39721743e+00,  2.55145991e+00,  2.76641960e+00]],
#
#        [[ 1.26111156e+00,  1.32652245e+00,  8.77368537e-02, ...,
#           3.85005429e-01,  9.91381733e-01,  1.24930893e+00],
#         [ 8.03734953e-01,  7.61840689e-01,  9.26076117e-01, ...,
#           6.82393428e-01,  9.67969635e-01,  5.78121940e-01],
#         [ 1.50776066e-02,  9.62968300e-01,  2.80321939e+00, ...,
#           1.46154651e+00,  1.92653347e+00,  1.73459806e+00],
#         ...,
#         [ 7.55673690e-02, -5.43359850e-03,  1.54435569e-01, ...,
#           1.65728018e-02,  1.42411334e-01,  5.09155496e-01],
#         [ 6.90692614e-01,  7.80389552e-01,  8.64844800e-01, ...,
#           8.85106016e-01,  8.76095194e-01,  5.12167870e-01],
#         [ 2.62225568e+00,  3.07839374e+00,  2.98959684e+00, ...,
#           2.39347361e+00,  2.55529150e+00,  2.76951884e+00]],
#
#        [[ 1.25863359e+00,  1.32733507e+00,  8.75209946e-02, ...,
#           3.84925773e-01,  9.88972142e-01,  1.24156173e+00],
#         [ 8.02700926e-01,  7.61671981e-01,  9.25625799e-01, ...,
#           6.82298968e-01,  9.67256828e-01,  5.77544327e-01],
#         [ 1.53272440e-02,  9.63680702e-01,  2.80643214e+00, ...,
#           1.46273733e+00,  1.91554073e+00,  1.73100912e+00],
#         ...,
#         [ 7.62436533e-02, -5.17018769e-03,  1.54060799e-01, ...,
#           1.65711383e-02,  1.43493582e-01,  5.12318255e-01],
#         [ 6.89800515e-01,  7.80165203e-01,  8.64405618e-01, ...,
#           8.84958690e-01,  8.75463324e-01,  5.11542967e-01],
#         [ 2.62941454e+00,  3.07968537e+00,  2.98861945e+00, ...,
#           2.39566951e+00,  2.53159860e+00,  2.77731172e+00]],
#
#        ...,
#
#        [[ 1.26186188e+00,  1.32708329e+00,  8.74163660e-02, ...,
#           3.84959419e-01,  9.90986323e-01,  1.24961250e+00],
#         [ 8.03979206e-01,  7.61869953e-01,  9.26017171e-01, ...,
#           6.82412373e-01,  9.67783120e-01,  5.78129939e-01],
#         [ 1.51293008e-02,  9.63222867e-01,  2.80658528e+00, ...,
#           1.46178986e+00,  1.92765577e+00,  1.73703201e+00],
#         ...,
#         [ 7.51633109e-02, -4.30493131e-03,  1.53830460e-01, ...,
#           1.65503330e-02,  1.41976138e-01,  5.08018292e-01],
#         [ 6.90916894e-01,  7.80431866e-01,  8.64793071e-01, ...,
#           8.85137657e-01,  8.75931298e-01,  5.12185095e-01],
#         [ 2.62242583e+00,  3.07819473e+00,  2.98730435e+00, ...,
#           2.39442734e+00,  2.56052542e+00,  2.76813350e+00]],
#
#        [[ 1.25701747e+00,  1.32702485e+00,  8.78681133e-02, ...,
#           3.84930541e-01,  9.92343243e-01,  1.24909006e+00],
#         [ 8.03547525e-01,  7.61816826e-01,  9.26324489e-01, ...,
#           6.82401627e-01,  9.67977563e-01,  5.78062488e-01],
#         [ 1.50186143e-02,  9.62819929e-01,  2.80035951e+00, ...,
#           1.46236971e+00,  1.92644733e+00,  1.73529409e+00],
#         ...,
#         [ 7.49912430e-02, -2.93057711e-03,  1.54536371e-01, ...,
#           1.65399194e-02,  1.42311290e-01,  5.08276689e-01],
#         [ 6.90552282e-01,  7.80361148e-01,  8.65096788e-01, ...,
#           8.85121546e-01,  8.76120014e-01,  5.12115254e-01],
#         [ 2.62488464e+00,  3.07772981e+00,  2.98973766e+00, ...,
#           2.39551980e+00,  2.55390687e+00,  2.76786963e+00]],
#
#        [[ 1.26566497e+00,  1.32773842e+00,  8.74660036e-02, ...,
#           3.85010285e-01,  9.91364248e-01,  1.25006618e+00],
#         [ 8.03696496e-01,  7.61845561e-01,  9.26006794e-01, ...,
#           6.82439244e-01,  9.67859466e-01,  5.77963090e-01],
#         [ 1.50696361e-02,  9.62990553e-01,  2.80781343e+00, ...,
#           1.46250604e+00,  1.92819618e+00,  1.73714410e+00],
#         ...,
#         [ 7.47807989e-02, -8.24978658e-03,  1.53771710e-01, ...,
#           1.65292354e-02,  1.41946600e-01,  5.07281373e-01],
#         [ 6.90664844e-01,  7.80395160e-01,  8.64779230e-01, ...,
#           8.85176749e-01,  8.75997672e-01,  5.11991805e-01],
#         [ 2.62517678e+00,  3.07811428e+00,  2.98765124e+00, ...,
#           2.39407506e+00,  2.56035871e+00,  2.76766039e+00]]])

# %%
filtered_celltypefrac_BLADE = pd.DataFrame(outcomes['BLADE']['Fraction'])
filtered_celltypefrac_BLADE
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.203741  0.231715  0.216827  0.238812  0.336297  0.205316  0.228220
# 1  0.053973  0.048428  0.033642  0.057604  0.082735  0.050630  0.095307
# 2  0.058477  0.073942  0.060768  0.071693  0.068023  0.055627  0.072331
# 3  0.091541  0.148503  0.122186  0.128048  0.105399  0.108828  0.101535
# 4  0.047581  0.044249  0.033974  0.047277  0.053619  0.043822  0.056773
# 5  0.034685  0.019134  0.017295  0.031519  0.038566  0.031544  0.040986
# 6  0.264119  0.102587  0.131659  0.164655  0.098735  0.270693  0.127745
# 7  0.017241  0.025758  0.019174  0.018043  0.026430  0.018967  0.029295
# 8  0.127103  0.104931  0.116625  0.109716  0.088016  0.094922  0.137421
# 9  0.101539  0.200753  0.247850  0.132632  0.102179  0.119650  0.110388
#
#          7         8         9         10        11        12        13  \
# 0  0.236456  0.200568  0.234780  0.185197  0.195042  0.206827  0.219747
# 1  0.048152  0.031864  0.051436  0.041525  0.033669  0.052700  0.057209
# 2  0.066484  0.060351  0.072212  0.057872  0.055522  0.057286  0.079907
# 3  0.127919  0.099956  0.112251  0.154354  0.114902  0.113316  0.210472
# 4  0.039281  0.035529  0.045587  0.035714  0.034069  0.034570  0.045681
# 5  0.026890  0.021181  0.029117  0.015213  0.019423  0.032886  0.023683
# 6  0.215020  0.104498  0.161110  0.073403  0.170673  0.257521  0.110517
# 7  0.027741  0.022490  0.025750  0.023600  0.021836  0.022527  0.026305
# 8  0.091571  0.089681  0.130692  0.078010  0.097335  0.093416  0.101992
# 9  0.120487  0.333881  0.137065  0.335112  0.257529  0.128950  0.124487
#
#          14        15        16
# 0  0.234669  0.199102  0.204632
# 1  0.048889  0.049616  0.053465
# 2  0.071840  0.106321  0.077223
# 3  0.174017  0.145528  0.209253
# 4  0.047626  0.045624  0.043039
# 5  0.022886  0.027511  0.023305
# 6  0.118776  0.109683  0.117511
# 7  0.031234  0.029980  0.035647
# 8  0.077124  0.102496  0.091508
# 9  0.172939  0.184139  0.144418

# %%
filtered_celltypefrac_BLADE.columns = df_TCGA_shared.columns

# %%
filtered_celltypefrac_BLADE.index = df_shared_mean.columns

# %%
list_ind = filtered_celltypefrac_BLADE.index.tolist()
# list_ind[6] = 'other'
filtered_celltypefrac_BLADE.index=list_ind

# %%
filtered_celltypefrac_BLADE
# Out:
#                     0         6         7         8        10        12  \
# B cell       0.203741  0.231715  0.216827  0.238812  0.336297  0.205316
# Dendritic    0.053973  0.048428  0.033642  0.057604  0.082735  0.050630
# Endothelial  0.058477  0.073942  0.060768  0.071693  0.068023  0.055627
# Fibroblast   0.091541  0.148503  0.122186  0.128048  0.105399  0.108828
# Macrophage   0.047581  0.044249  0.033974  0.047277  0.053619  0.043822
# Mast         0.034685  0.019134  0.017295  0.031519  0.038566  0.031544
# T cell       0.264119  0.102587  0.131659  0.164655  0.098735  0.270693
# myocyte      0.017241  0.025758  0.019174  0.018043  0.026430  0.018967
# other        0.127103  0.104931  0.116625  0.109716  0.088016  0.094922
# tumor        0.101539  0.200753  0.247850  0.132632  0.102179  0.119650
#
#                    13        16        17        18        20        22  \
# B cell       0.228220  0.236456  0.200568  0.234780  0.185197  0.195042
# Dendritic    0.095307  0.048152  0.031864  0.051436  0.041525  0.033669
# Endothelial  0.072331  0.066484  0.060351  0.072212  0.057872  0.055522
# Fibroblast   0.101535  0.127919  0.099956  0.112251  0.154354  0.114902
# Macrophage   0.056773  0.039281  0.035529  0.045587  0.035714  0.034069
# Mast         0.040986  0.026890  0.021181  0.029117  0.015213  0.019423
# T cell       0.127745  0.215020  0.104498  0.161110  0.073403  0.170673
# myocyte      0.029295  0.027741  0.022490  0.025750  0.023600  0.021836
# other        0.137421  0.091571  0.089681  0.130692  0.078010  0.097335
# tumor        0.110388  0.120487  0.333881  0.137065  0.335112  0.257529
#
#                    23        24        25        26        28
# B cell       0.206827  0.219747  0.234669  0.199102  0.204632
# Dendritic    0.052700  0.057209  0.048889  0.049616  0.053465
# Endothelial  0.057286  0.079907  0.071840  0.106321  0.077223
# Fibroblast   0.113316  0.210472  0.174017  0.145528  0.209253
# Macrophage   0.034570  0.045681  0.047626  0.045624  0.043039
# Mast         0.032886  0.023683  0.022886  0.027511  0.023305
# T cell       0.257521  0.110517  0.118776  0.109683  0.117511
# myocyte      0.022527  0.026305  0.031234  0.029980  0.035647
# other        0.093416  0.101992  0.077124  0.102496  0.091508
# tumor        0.128950  0.124487  0.172939  0.184139  0.144418

# %%
# ignore this block and above
# use code in runMuSiC to store and access celltypefrac file
filtered_celltypefrac_BLADE.T.to_csv("/home/cke/BLADE/data/filtered_celltypefrac_BLADE_pseudobulk.csv")
